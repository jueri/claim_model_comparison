# %% [markdown]
# # BERT

# %%
import os

import numpy as np
import tensorflow as tf
import wandb
from sklearn.metrics import (accuracy_score, classification_report,
                             f1_score, precision_score,
                             recall_score)
from sklearn.model_selection import train_test_split
from transformers import (DistilBertTokenizer,
                          TFDistilBertForSequenceClassification)
from wandb.keras import WandbCallback

from src.dataset import load_dataset
from src.evaluation import confusion_matrix_plot, acc_plot
from config import DATASETS, PROJECT_NAME

# %%
MODEL_NAME = "deepset/gbert-base"
TRACKING = True
FALSE_CLASS_BALANCE = 1.0

# dataset = DATASETS["dataset_1418"]
# dataset = DATASETS["SMC_2000"]
# dataset = DATASETS["SMC_1000"]
dataset = DATASETS["SMC_Full"]
# dataset = DATASETS["complete"]

# %% [markdown]
# ### 0. Load data

# %%
train_text_split, X_test, train_labels_split, y_test = load_dataset(dataset_path=os.path.join(dataset["base_path"], dataset["data"]), false_class_balance=FALSE_CLASS_BALANCE)

# %%
y_train = train_labels_split.apply(lambda x: 0 if x==False else 1)
y_test = y_test.apply(lambda x: 0 if x==False else 1)

# %%
X_train, X_val, y_train, y_val = train_test_split(train_text_split, train_labels_split, test_size=.2, random_state=42) # train/test

# %%
print(X_train.size)
print(X_val.size)
print(y_train.size)
# Out:
# 3834
# 960
# 1278

# %% [markdown]
# ### 1. Prepare dataset

# %%
tokenizer = DistilBertTokenizer.from_pretrained(MODEL_NAME) # load tokenizer
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BertTokenizer'.
# The class this function is called from is 'DistilBertTokenizer'.

# %%
def tokenize_dataset(dataset):
    """Tokenize a list of strings for the BERT model."""
    encoded = tokenizer(
        dataset,
        padding=True,
        truncation=True,
        return_tensors='np',
    )
    return encoded.data

# %%
encodet_train_text = tokenize_dataset(X_train["Sentence"].to_list())
encodet_val_texts = tokenize_dataset(X_val["Sentence"].to_list())
encodet_test_texts = tokenize_dataset(X_test["Sentence"].to_list())

# %% [markdown]
# ### 2. Create Model

# %%
model = TFDistilBertForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=2)  # Load model
# Out:
# 2022-02-05 11:14:45.579983: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-05 11:14:45.589099: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-05 11:14:45.589730: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-05 11:14:45.590805: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-05 11:14:45.591595: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-05 11:14:45.592251: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-05 11:14:45.592889: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-05 11:14:45.994393: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-05 11:14:45.994717: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-05 11:14:45.994989: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-05 11:14:45.995238: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7307 MB memory:  -> device: 0, name: GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2022-02-05 11:14:46.066464: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# Some layers from the model checkpoint at deepset/gbert-base were not used when initializing TFDistilBertForSequenceClassification: ['mlm___cls', 'nsp___cls', 'bert']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at deepset/gbert-base and are newly initialized: ['dropout_37', 'distilbert', 'classifier', 'pre_classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Set hyperparameter
# learning_rate = 0.005
# learning_rate = 0.001
# learning_rate = 0.0005
# learning_rate = 0.0001
# learning_rate = 0.00005
learning_rate = 0.00001

#learning_rate = 1e-5
epochs = 3
batch_size = 16

# %%
# from tensorflow.keras.optimizers.schedules import PolynomialDecay

# num_train_steps = (len(encodet_train_text['input_ids']) // batch_size) * epochs

# lr_scheduler = PolynomialDecay(
#     initial_learning_rate=5e-5,
#     end_learning_rate=0.,
#     decay_steps=num_train_steps
#     )

# %%
model = TFDistilBertForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=2)

loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),

optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
# optimizer = tf.keras.optimizers.Adam(learning_rate=lr_scheduler)
# Out:
# Some layers from the model checkpoint at deepset/gbert-base were not used when initializing TFDistilBertForSequenceClassification: ['mlm___cls', 'nsp___cls', 'bert']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at deepset/gbert-base and are newly initialized: ['distilbert', 'classifier', 'dropout_75', 'pre_classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.compile(
    optimizer=optimizer, 
    loss=loss,
    metrics=tf.metrics.SparseCategoricalAccuracy(),
    )

# %%
model.summary()
# Out:
# Model: "tf_distil_bert_for_sequence_classification_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  distilbert (TFDistilBertMai  multiple                 109335552
#  nLayer)
#
#  pre_classifier (Dense)      multiple                  590592
#
#  classifier (Dense)          multiple                  1538
#
#  dropout_75 (Dropout)        multiple                  0
#
# =================================================================
# Total params: 109,927,682
# Trainable params: 109,927,682
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 3. Train model

# %%
if TRACKING:
  report = []
  model.summary(print_fn=lambda x: report.append(x))

  wandb.init(project=PROJECT_NAME,
          config={
              "model": MODEL_NAME,
              "setup": "\n".join(report),
              "dataset": dataset["name"],
              "train_data_size": len(X_train),
              "validation_data_size": len(X_val),
              "test_data_size": len(X_test),
              "batch_size": batch_size,
              "learning_rate": learning_rate,
              "epochs": epochs,
              "false_class_balance": FALSE_CLASS_BALANCE
          })
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: jueri (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.10 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/jueri/sweep/runs/28j0p1y8" target="_blank">solar-serenity-25</a></strong> to <a href="https://wandb.ai/jueri/sweep" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>

# %%
history = model.fit(
      encodet_train_text,
      np.array(y_train), 
      validation_data=(encodet_val_texts, np.array(y_val)),
      epochs=epochs, 
      batch_size=batch_size,
      # callbacks=[WandbCallback()]
      )
# Out:
# Epoch 1/3
# 80/80 [==============================] - ETA: 0s - loss: 0.6029 - sparse_categorical_accuracy: 0.6565
# wandb: ERROR Can't save model, h5py returned error: Saving the model to HDF5 format requires the model to be a Functional model or a Sequential model. It does not work for subclassed models, because such models are defined via the body of a Python method, which isn't safely serializable. Consider saving to the Tensorflow SavedModel format (by setting save_format="tf") or using `save_weights`.
# 80/80 [==============================] - 31s 247ms/step - loss: 0.6029 - sparse_categorical_accuracy: 0.6565 - val_loss: 0.6149 - val_sparse_categorical_accuracy: 0.6781
# Epoch 2/3
# 80/80 [==============================] - 18s 231ms/step - loss: 0.4807 - sparse_categorical_accuracy: 0.7762 - val_loss: 0.4985 - val_sparse_categorical_accuracy: 0.7812
# Epoch 3/3
# 80/80 [==============================] - 19s 232ms/step - loss: 0.3343 - sparse_categorical_accuracy: 0.8615 - val_loss: 0.3178 - val_sparse_categorical_accuracy: 0.8750

# %% [markdown]
# ### 4. Evaluate results

# %%
test_loss, test_accuracy = model.evaluate(encodet_test_texts, np.array(y_test))
# Out:
# 13/13 [==============================] - 4s 156ms/step - loss: 0.3385 - sparse_categorical_accuracy: 0.8725

# %%
preds = model.predict(encodet_test_texts)

# %%
y_pred = np.argmax(preds.logits, axis=1)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87       198
#            1       0.86      0.89      0.88       202
#
#     accuracy                           0.87       400
#    macro avg       0.87      0.87      0.87       400
# weighted avg       0.87      0.87      0.87       400

# %%
f1 = f1_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

# %%
if TRACKING:
    wandb.log({'test_f1': f1})
    wandb.log({'test_recall': recall})
    wandb.log({'test_precision': precision})
    wandb.log({'test_accuracy': accuracy})
    wandb.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 33270... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▅█</td></tr><tr><td>loss</td><td>█▅▁</td></tr><tr><td>sparse_categorical_accuracy</td><td>▁▅█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>val_loss</td><td>█▅▁</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>▁▅█</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>2</td></tr><tr><td>best_val_loss</td><td>0.3178</td></tr><tr><td>epoch</td><td>2</td></tr><tr><td>loss</td><td>0.33435</td></tr><tr><td>sparse_categorical_accuracy</td><td>0.8615</td></tr><tr><td>test_accuracy</td><td>0.8725</td></tr><tr><td>test_f1</td><td>0.87531</td></tr><tr><td>test_precision</td><td>0.86473</td></tr><tr><td>test_recall</td><td>0.88614</td></tr><tr><td>val_loss</td><td>0.3178</td></tr><tr><td>val_sparse_categorical_accuracy</td><td>0.875</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">solar-serenity-25</strong>: <a href="https://wandb.ai/jueri/sweep/runs/28j0p1y8" target="_blank">https://wandb.ai/jueri/sweep/runs/28j0p1y8</a><br/>
# Find logs at: <code>./wandb/run-20220205_111449-28j0p1y8/logs</code><br/>

# %%
SAVE = False

# %%
import matplotlib.pyplot as plt  # type: ignore
import matplotlib as mlp

import tikzplotlib

def acc_plot(history):
    mlp.style.use('default')
    
    acc = history.history.get("sparse_categorical_accuracy")
    val_acc = history.history.get("val_sparse_categorical_accuracy")
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]



    epochs = range(1, len(acc)+1)


    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 4), constrained_layout=False)
    
    fig.suptitle('Training and validation results', fontsize=16)
    # ax1.plot(x, y)
    # ax2.plot(x, -y)


    ax1.plot(epochs, acc, "bo", label="Training accuracy")
    ax1.plot(epochs, val_acc, "b", label="Validation accuracy")
    ax1.set_title("Accuracy")
    ax1.set(xlabel='Epoch', ylabel='Accuracy')
    ax1.set_xticks(range(1, len(acc)+1), step=1)
    ax1.legend()
    ax1.grid()

    # plt.figure()

    ax2.plot(epochs, loss, "bo", label="Training loss")
    ax2.plot(epochs, val_loss, "b", label="Validation loss")
    ax2.set_title("Loss")
    ax2.set(xlabel='Epoch', ylabel='Loss')
    ax2.set_xticks(range(1, len(acc)+1), step=1)
    ax2.legend()
    ax2.grid()

    if SAVE:
        tikzplotlib.save("overfitting.tex")

    fig.show()

acc_plot(history)
# Out:
# /tmp/ipykernel_33157/2769343766.py:47: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import itertools
from sklearn.metrics import confusion_matrix  # type: ignore


def confusion_matrix_plot2(
    y_test, y_pred, label, title: str
):
    
    cm = confusion_matrix(y_test, y_pred)
    mlp.style.use('default')

    cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.grid(False)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    target_names = [i for i in label]

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names)
        plt.yticks(tick_marks, target_names)


    thresh = cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            plt.text(j, i, "{:,}".format(cm[i, j]),
                    horizontalalignment="center",
                    color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    if SAVE:
        tikzplotlib.save("final_model_confusion_matrix_87.tex")
    plt.show()

confusion_matrix_plot2(y_test, y_pred, label=[False, True], title="Results confusion matrix")

# %%
if SAVE:
  model.save_pretrained(os.path.join("data", "models", dataset["name"] + "_87"))
